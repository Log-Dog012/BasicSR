# %% [markdown]
# # SwinIR SEM 微调 — 正式训练
#
# GPU: 2×T4 | Checkpoint: 10k iter | 目标: 70k iter
#
# **策略**：
# 1. 先跑 200 iter 试运行（验证训练能启动、ETA 合理）
# 2. 确认无误后，跑完整训练
# 3. 训练完成后下载 output 中的模型和日志

# %% [markdown]
# ## 0. 环境准备（与 check.ipynb 相同）

# %%
import torch
NUM_GPUS = torch.cuda.device_count()
print(f'PyTorch: {torch.__version__}, CUDA: {torch.cuda.is_available()}, GPUs: {NUM_GPUS}')
for i in range(NUM_GPUS):
    p = torch.cuda.get_device_properties(i)
    mem = getattr(p, 'total_memory', getattr(p, 'total_mem', 0))
    print(f'  GPU {i}: {p.name} — {mem/1e9:.1f} GB')

# 按 GPU 数量和速度预估安全的 total_iter
# P100 ≈ 1.0s/iter, T4 ≈ 1.2s/iter, 取保守值 1.2s
SEC_PER_ITER = 1.2
MAX_SECONDS = 11.5 * 3600  # 留 30min 余量
MAX_NEW_ITERS = int(MAX_SECONDS / SEC_PER_ITER / NUM_GPUS) if NUM_GPUS > 0 else 35000
TOTAL_ITER = 10000 + MAX_NEW_ITERS
print(f'\n预估: {NUM_GPUS}×GPU, ~{SEC_PER_ITER}s/iter → total_iter={TOTAL_ITER} (安全值)')
# Out:
# PyTorch: 2.10.0+cu128, CUDA: True, GPUs: 2
#   GPU 0: Tesla T4 — 15.6 GB
#   GPU 1: Tesla T4 — 15.6 GB
#
# 预估: 2×GPU, ~1.2s/iter → total_iter=27250 (安全值)

# %%
import os, shutil
WORK_DIR = '/kaggle/working'
os.chdir(WORK_DIR)

# 克隆仓库
if not os.path.exists('BasicSR'):
    # !git clone https://github.com/Log-Dog012/BasicSR.git
    # !cd BasicSR && git checkout cuda-sem-finetune

# 安装依赖
os.chdir('BasicSR')
# !pip install -r requirements.txt -q
# !pip install -e . -q
# !pip install lpips timm -q
print('✅ 环境就绪')
# Out:
# Cloning into 'BasicSR'...
# remote: Enumerating objects: 4830, done.
# remote: Counting objects: 100% (141/141), done.
# remote: Compressing objects: 100% (85/85), done.
# remote: Total 4830 (delta 84), reused 88 (delta 56), pack-reused 4689 (from 3)
# Receiving objects: 100% (4830/4830), 4.07 MiB | 14.09 MiB/s, done.
# Resolving deltas: 100% (3200/3200), done.
# Already on 'cuda-sem-finetune'
# Your branch is up to date with 'origin/cuda-sem-finetune'.
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 46.8/46.8 kB 787.3 kB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 338.3/338.3 kB 3.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.5/5.5 MB 33.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 256.2/256.2 kB 22.3 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 53.8/53.8 kB 834.9 kB/s eta 0:00:00
# ✅ 环境就绪

# %%
# 复制模型文件
MODEL_INPUT = '/kaggle/input/models/logdog012/swinir-finetune/pytorch/default/1'
swinir_zoo = os.path.join(WORK_DIR, 'BasicSR', 'SwinIR', 'model_zoo')
exp_dir = os.path.join(WORK_DIR, 'BasicSR', 'experiments', 'finetune_SwinIR_SRx4_SEM')

# 预训练权重
os.makedirs(swinir_zoo, exist_ok=True)
for root, dirs, files in os.walk(MODEL_INPUT):
    for f in files:
        if 'classicalSR' in f and f.endswith('.pth'):
            shutil.copy2(os.path.join(root, f), os.path.join(swinir_zoo, f))
            print(f'✅ 预训练: {f}')
            break

# Checkpoint
for name in ['net_g_10000.pth', '10000.state']:
    for root, dirs, files in os.walk(MODEL_INPUT):
        if name in files:
            dst_dir = os.path.join(exp_dir, 'models' if 'pth' in name else 'training_states')
            os.makedirs(dst_dir, exist_ok=True)
            shutil.copy2(os.path.join(root, name), os.path.join(dst_dir, name))
            print(f'✅ {name}')
            break
print('✅ 模型文件就绪')
# Out:
# ✅ 预训练: 001_classicalSR_DIV2K_s48w8_SwinIR-M_x4.pth
# ✅ net_g_10000.pth
# ✅ 10000.state
# ✅ 模型文件就绪

# %% [markdown]
# ## 1. 正式训练
#
# 根据 GPU 数量自动计算安全的 `total_iter`（留 30min 余量防 12h 超时）。
# - 2×T4: ~39000 iter → total_iter=49000
# - 1×P100: ~32000 iter → total_iter=42000
# - `auto_resume` 确保超时后下次运行自动恢复

# %%
# 正式训练 — 自适应 GPU 数量
# --force_yml 覆盖 total_iter 为安全值，不改原 YAML
import subprocess, sys

print(f'开始正式训练 ({TOTAL_ITER} iter, {NUM_GPUS}×GPU)...')
print('='*50)

if NUM_GPUS >= 2:
    # DDP 多卡
    # !torchrun --nproc_per_node={NUM_GPUS} --master_port=4321 -m basicsr.train \
      -opt options/train/SwinIR/finetune_SwinIR_SRx4_SEM.yml \
      --launcher pytorch --auto_resume \
      --force_yml train:total_iter={TOTAL_ITER}
else:
    # 单卡，不用 torchrun
    # !python -m basicsr.train \
      -opt options/train/SwinIR/finetune_SwinIR_SRx4_SEM.yml \
      --auto_resume \
      --force_yml train:total_iter={TOTAL_ITER}
# Out:
# 开始正式训练 (27250 iter, 2×GPU)...
# ==================================================
# W0709 17:47:58.745000 128 torch/distributed/run.py:852]
# W0709 17:47:58.745000 128 torch/distributed/run.py:852] *****************************************
# W0709 17:47:58.745000 128 torch/distributed/run.py:852] Setting OMP_NUM_THREADS environment variable for each process to be 1 in default, to avoid your system being overloaded, please further tune the variable for optimal performance in your application as needed.
# W0709 17:47:58.745000 128 torch/distributed/run.py:852] *****************************************
# <frozen runpy>:128: RuntimeWarning: 'basicsr.train' found in sys.modules after import of package 'basicsr', but prior to execution of 'basicsr.train'; this may result in unpredictable behaviour
# <frozen runpy>:128: RuntimeWarning: 'basicsr.train' found in sys.modules after import of package 'basicsr', but prior to execution of 'basicsr.train'; this may result in unpredictable behaviour
# pretrain_network path will be ignored during resuming.
# Set pretrain_network_g to /kaggle/working/BasicSR/experiments/finetune_SwinIR_SRx4_SEM/models/net_g_10000.pth
# pretrain_network path will be ignored during resuming.
# Set pretrain_network_g to /kaggle/working/BasicSR/experiments/finetune_SwinIR_SRx4_SEM/models/net_g_10000.pth
# 2026-07-09 17:48:08,701 INFO:
#                 ____                _       _____  ____
#                / __ ) ____ _ _____ (_)_____/ ___/ / __ \
#               / __  |/ __ `// ___// // ___/\__ \ / /_/ /
#              / /_/ // /_/ /(__  )/ // /__ ___/ // _, _/
#             /_____/ \__,_//____//_/ \___//____//_/ |_|
#      ______                   __   __                 __      __
#     / ____/____   ____   ____/ /  / /   __  __ _____ / /__   / /
#    / / __ / __ \ / __ \ / __  /  / /   / / / // ___// //_/  / /
#   / /_/ // /_/ // /_/ // /_/ /  / /___/ /_/ // /__ / /<    /_/
#   \____/ \____/ \____/ \____/  /_____/\____/ \___//_/|_|  (_)
#
# Version Information:
# 	BasicSR: 1.4.2
# 	PyTorch: 2.10.0+cu128
# 	TorchVision: 0.25.0+cu128
# 2026-07-09 17:48:08,701 INFO:
#   name: finetune_SwinIR_SRx4_SEM
#   model_type: SwinIRModel
#   scale: 4
#   num_gpu: 2
#   manual_seed: 0
#   datasets:[
#     train:[
#       name: SEM
#       type: PairedImageDataset
#       dataroot_gt: /kaggle/input/datasets/logdog012/swinir-finetune/train_sem_hr/HR
#       dataroot_lq: /kaggle/input/datasets/logdog012/swinir-finetune/train_sem_lr_x4/LR_x4
#       filename_tmpl: {}
#       io_backend:[
#         type: disk
#       ]
#       gt_size: 192
#       use_hflip: True
#       use_rot: True
#       num_worker_per_gpu: 6
#       batch_size_per_gpu: 8
#       dataset_enlarge_ratio: 1
#       prefetch_mode: None
#       phase: train
#       scale: 4
#     ]
#     val:[
#       name: LVSEM_eval
#       type: PairedImageDataset
#       dataroot_gt: /kaggle/input/datasets/logdog012/swinir-finetune/eval_sem/eval/SEMimg
#       dataroot_lq: /kaggle/input/datasets/logdog012/swinir-finetune/eval_sem/eval/LR
#       io_backend:[
#         type: disk
#       ]
#       phase: val
#       scale: 4
#     ]
#   ]
#   network_g:[
#     type: SwinIR
#     upscale: 4
#     in_chans: 3
#     img_size: 48
#     window_size: 8
#     img_range: 1.0
#     depths: [6, 6, 6, 6, 6, 6]
#     embed_dim: 180
#     num_heads: [6, 6, 6, 6, 6, 6]
#     mlp_ratio: 2
#     upsampler: pixelshuffle
#     resi_connection: 1conv
#   ]
#   path:[
#     pretrain_network_g: /kaggle/working/BasicSR/experiments/finetune_SwinIR_SRx4_SEM/models/net_g_10000.pth
#     strict_load_g: False
#     resume_state: /kaggle/working/BasicSR/experiments/finetune_SwinIR_SRx4_SEM/training_states/10000.state
#     experiments_root: /kaggle/working/BasicSR/experiments/finetune_SwinIR_SRx4_SEM
#     models: /kaggle/working/BasicSR/experiments/finetune_SwinIR_SRx4_SEM/models
#     training_states: /kaggle/working/BasicSR/experiments/finetune_SwinIR_SRx4_SEM/training_states
#     log: /kaggle/working/BasicSR/experiments/finetune_SwinIR_SRx4_SEM
#     visualization: /kaggle/working/BasicSR/experiments/finetune_SwinIR_SRx4_SEM/visualization
#   ]
#   auto_resume: True
#   train:[
#     ema_decay: 0.999
#     optim_g:[
#       type: Adam
#       lr: 0.0001
#       weight_decay: 0
#       betas: [0.9, 0.99]
#     ]
#     scheduler:[
#       type: MultiStepLR
#       milestones: [30000, 50000, 60000, 65000]
#       gamma: 0.5
#     ]
#     total_iter: 27250
#     warmup_iter: -1
#     pixel_opt:[
#       type: L1Loss
#       loss_weight: 1.0
#       reduction: mean
#     ]
#   ]
#   logger:[
#     print_freq: 100
#     save_checkpoint_freq: 5000.0
#     use_tb_logger: True
#   ]
#   dist_params:[
#     backend: nccl
#     port: 29500
#   ]
#   dist: True
#   rank: 0
#   world_size: 2
#   is_train: True
#   dtype: torch.float32
#   root_path: /kaggle/working/BasicSR
#
# /usr/local/lib/python3.12/dist-packages/torch/utils/data/dataloader.py:424: UserWarning: This DataLoader will create 6 worker processes in total. Our suggested max number of worker in current system is 4, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   self.check_worker_number_rationality()
# 2026-07-09 17:48:47,556 INFO: Dataset [PairedImageDataset] - SEM is built.
# /usr/local/lib/python3.12/dist-packages/torch/utils/data/dataloader.py:424: UserWarning: This DataLoader will create 6 worker processes in total. Our suggested max number of worker in current system is 4, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   self.check_worker_number_rationality()
# 2026-07-09 17:48:47,557 INFO: Training statistics:
# 	Number of train images: 19256
# 	Dataset enlarge ratio: 1
# 	Batch size per gpu: 8
# 	World size (gpu number): 2
# 	Require iter number per epoch: 1204
# 	Total epochs: 23; iters: 27250.
# 2026-07-09 17:48:48,277 INFO: Dataset [PairedImageDataset] - LVSEM_eval is built.
# 2026-07-09 17:48:48,277 INFO: Number of val images/folders in LVSEM_eval: 210
# /usr/local/lib/python3.12/dist-packages/torch/functional.py:505: UserWarning: torch.meshgrid: in an upcoming release, it will be required to pass the indexing argument. (Triggered internally at /pytorch/aten/src/ATen/native/TensorShape.cpp:4381.)
#   return _VF.meshgrid(tensors, **kwargs)  # type: ignore[attr-defined]
# /usr/local/lib/python3.12/dist-packages/torch/functional.py:505: UserWarning: torch.meshgrid: in an upcoming release, it will be required to pass the indexing argument. (Triggered internally at /pytorch/aten/src/ATen/native/TensorShape.cpp:4381.)
#   return _VF.meshgrid(tensors, **kwargs)  # type: ignore[attr-defined]
# 2026-07-09 17:48:48,598 INFO: Network [SwinIR] is created.
# 2026-07-09 17:48:49,083 INFO: Network: DistributedDataParallel - SwinIR, with parameters: 11,900,199
# 2026-07-09 17:48:49,083 INFO: SwinIR(
#   (conv_first): Conv2d(3, 180, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (patch_embed): PatchEmbed(
#     (norm): LayerNorm((180,), eps=1e-05, elementwise_affine=True)
#   )
#   (patch_unembed): PatchUnEmbed()
#   (pos_drop): Dropout(p=0.0, inplace=False)
#   (layers): ModuleList(
#     (0): RSTB(
#       (residual_group): BasicLayer(
#         dim=180, input_resolution=(48, 48), depth=6
#         (blocks): ModuleList(
#           (0): SwinTransformerBlock(
#             dim=180, input_resolution=(48, 48), num_heads=6, window_size=8, shift_size=0, mlp_ratio=2
#             (norm1): LayerNorm((180,), eps=1e-05, elementwise_affine=True)
#             (attn): WindowAttention(
#               dim=180, window_size=(8, 8), num_heads=6
#               (qkv): Linear(in_features=180, out_features=540, bias=True)
#               (attn_drop): Dropout(p=0.0, inplace=False)
#               (proj): Linear(in_features=180, out_features=180, bias=True)
#               (proj_drop): Dropout(p=0.0, inplace=False)
#               (softmax): Softmax(dim=-1)
#             )
#             (drop_path): Identity()
#             (norm2): LayerNorm((180,), eps=1e-05, elementwise_affine=True)
#             (mlp): Mlp(
#               (fc1): Linear(in_features=180, out_features=360, bias=True)
#               (act): GELU(approximate='none')
#               (fc2): Linear(in_features=360, out_features=180, bias=True)
#               (drop): Dropout(p=0.0, inplace=False)
#             )
#           )
#           (1): SwinTransformerBlock(
#             dim=180, input_resolution=(48, 48), num_heads=6, window_size=8, shift_size=4, mlp_ratio=2
#             (norm1): LayerNorm((180,), eps=1e-05, elementwise_affine=True)
#             (attn): WindowAttention(
#               dim=180, window_size=(8, 8), num_heads=6
#               (qkv): Linear(in_features=180, out_features=540, bias=True)
#               (attn_drop): Dropout(p=0.0, inplace=False)
#               (proj): Linear(in_features=180, out_features=180, bias=True)
#               (proj_drop): Dropout(p=0.0, inplace=False)
#               (softmax): Softmax(dim=-1)
#             )
#             (drop_path): DropPath()
#             (norm2): LayerNorm((180,), eps=1e-05, elementwise_affine=True)
#             (mlp): Mlp(
#               (fc1): Linear(in_features=180, out_features=360, bias=True)
#               (act): GELU(approximate='none')
#               (fc2): Linear(in_features=360, out_features=180, bias=True)
#               (drop): Dropout(p=0.0, inplace=False)
#             )
#           )
#           (2): SwinTransformerBlock(
#             dim=180, input_resolution=(48, 48), num_heads=6, window_size=8, shift_size=0, mlp_ratio=2
#             (norm1): LayerNorm((180,), eps=1e-05, elementwise_affine=True)
#             (attn): WindowAttention(
#               dim=180, window_size=(8, 8), num_heads=6
#               (qkv): Linear(in_features=180, out_features=540, bias=True)
#               (attn_drop): Dropout(p=0.0, inplace=False)
#               (proj): Linear(in_features=180, out_features=180, bias=True)
#               (proj_drop): Dropout(p=0.0, inplace=False)
#               (softmax): Softmax(dim=-1)
#             )
#             (drop_path): DropPath()
#             (norm2): LayerNorm((180,), eps=1e-05, elementwise_affine=True)
#             (mlp): Mlp(
#               (fc1): Linear(in_features=180, out_features=360, bias=True)
#               (act): GELU(approximate='none')
#               (fc2): Linear(in_features=360, out_features=180, bias=True)
#               (drop): Dropout(p=0.0, inplace=False)
#             )
#           )
#           (3): SwinTransformerBlock(
#             dim=180, input_resolution=(48, 48), num_heads=6, window_size=8, shift_size=4, mlp_ratio=2
#             (norm1): LayerNorm((180,), eps=1e-05, elementwise_affine=True)
#             (attn): WindowAttention(
#               dim=180, window_size=(8, 8), num_heads=6
#               (qkv): Linear(in_features=180, out_features=540, bias=True)
#               (attn_drop): Dropout(p=0.0, inplace=False)
#               (proj): Linear(in_features=180, out_features=180, bias=True)
#               (proj_drop): Dropout(p=0.0, inplace=False)
#               (softmax): Softmax(dim=-1)
#             )
#             (drop_path): DropPath()
#             (norm2): LayerNorm((180,), eps=1e-05, elementwise_affine=True)
#             (mlp): Mlp(
#               (fc1): Linear(in_features=180, out_features=360, bias=True)
#               (act): GELU(approximate='none')
#               (fc2): Linear(in_features=360, out_features=180, bias=True)
#               (drop): Dropout(p=0.0, inplace=False)
#             )
#           )
#           (4): SwinTransformerBlock(
#             dim=180, input_resolution=(48, 48), num_heads=6, window_size=8, shift_size=0, mlp_ratio=2
#             (norm1): LayerNorm((180,), eps=1e-05, elementwise_affine=True)
#             (attn): WindowAttention(
#               dim=180, window_size=(8, 8), num_heads=6
#               (qkv): Linear(in_features=180, out_features=540, bias=True)
#               (attn_drop): Dropout(p=0.0, inplace=False)
#               (proj): Linear(in_features=180, out_features=180, bias=True)
#               (proj_drop): Dropout(p=0.0, inplace=False)
#               (softmax): Softmax(dim=-1)
#             )
#             (drop_path): DropPath()
#             (norm2): LayerNorm((180,), eps=1e-05, elementwise_affine=True)
#             (mlp): Mlp(
#               (fc1): Linear(in_features=180, out_features=360, bias=True)
#               (act): GELU(approximate='none')
#               (fc2): Linear(in_features=360, out_features=180, bias=True)
#               (drop): Dropout(p=0.0, inplace=False)
#             )
#           )
#           (5): SwinTransformerBlock(
#             dim=180, input_resolution=(48, 48), num_heads=6, window_size=8, shift_size=4, mlp_ratio=2
#             (norm1): LayerNorm((180,), eps=1e-05, elementwise_affine=True)
#             (attn): WindowAttention(
#               dim=180, window_size=(8, 8), num_heads=6
#               (qkv): Linear(in_features=180, out_features=540, bias=True)
#               (attn_drop): Dropout(p=0.0, inplace=False)
#               (proj): Linear(in_features=180, out_features=180, bias=True)
#               (proj_drop): Dropout(p=0.0, inplace=False)
#               (softmax): Softmax(dim=-1)
#             )
#             (drop_path): DropPath()
#             (norm2): LayerNorm((180,), eps=1e-05, elementwise_affine=True)
#             (mlp): Mlp(
#               (fc1): Linear(in_features=180, out_features=360, bias=True)
#               (act): GELU(approximate='none')
#               (fc2): Linear(in_features=360, out_features=180, bias=True)
#               (drop): Dropout(p=0.0, inplace=False)
#             )
#           )
#         )
#       )
#       (conv): Conv2d(180, 180, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (patch_embed): PatchEmbed()
#       (patch_unembed): PatchUnEmbed()
#     )
#     (1-5): 5 x RSTB(
#       (residual_group): BasicLayer(
#         dim=180, input_resolution=(48, 48), depth=6
#         (blocks): ModuleList(
#           (0): SwinTransformerBlock(
#             dim=180, input_resolution=(48, 48), num_heads=6, window_size=8, shift_size=0, mlp_ratio=2
#             (norm1): LayerNorm((180,), eps=1e-05, elementwise_affine=True)
#             (attn): WindowAttention(
#               dim=180, window_size=(8, 8), num_heads=6
#               (qkv): Linear(in_features=180, out_features=540, bias=True)
#               (attn_drop): Dropout(p=0.0, inplace=False)
#               (proj): Linear(in_features=180, out_features=180, bias=True)
#               (proj_drop): Dropout(p=0.0, inplace=False)
#               (softmax): Softmax(dim=-1)
#             )
#             (drop_path): DropPath()
#             (norm2): LayerNorm((180,), eps=1e-05, elementwise_affine=True)
#             (mlp): Mlp(
#               (fc1): Linear(in_features=180, out_features=360, bias=True)
#               (act): GELU(approximate='none')
#               (fc2): Linear(in_features=360, out_features=180, bias=True)
#               (drop): Dropout(p=0.0, inplace=False)
#             )
#           )
#           (1): SwinTransformerBlock(
#             dim=180, input_resolution=(48, 48), num_heads=6, window_size=8, shift_size=4, mlp_ratio=2
#             (norm1): LayerNorm((180,), eps=1e-05, elementwise_affine=True)
#             (attn): WindowAttention(
#               dim=180, window_size=(8, 8), num_heads=6
#               (qkv): Linear(in_features=180, out_features=540, bias=True)
#               (attn_drop): Dropout(p=0.0, inplace=False)
#               (proj): Linear(in_features=180, out_features=180, bias=True)
#               (proj_drop): Dropout(p=0.0, inplace=False)
#               (softmax): Softmax(dim=-1)
#             )
#             (drop_path): DropPath()
#             (norm2): LayerNorm((180,), eps=1e-05, elementwise_affine=True)
#             (mlp): Mlp(
#               (fc1): Linear(in_features=180, out_features=360, bias=True)
#               (act): GELU(approximate='none')
#               (fc2): Linear(in_features=360, out_features=180, bias=True)
#               (drop): Dropout(p=0.0, inplace=False)
#             )
#           )
#           (2): SwinTransformerBlock(
#             dim=180, input_resolution=(48, 48), num_heads=6, window_size=8, shift_size=0, mlp_ratio=2
#             (norm1): LayerNorm((180,), eps=1e-05, elementwise_affine=True)
#             (attn): WindowAttention(
#               dim=180, window_size=(8, 8), num_heads=6
#               (qkv): Linear(in_features=180, out_features=540, bias=True)
#               (attn_drop): Dropout(p=0.0, inplace=False)
#               (proj): Linear(in_features=180, out_features=180, bias=True)
#               (proj_drop): Dropout(p=0.0, inplace=False)
#               (softmax): Softmax(dim=-1)
#             )
#             (drop_path): DropPath()
#             (norm2): LayerNorm((180,), eps=1e-05, elementwise_affine=True)
#             (mlp): Mlp(
#               (fc1): Linear(in_features=180, out_features=360, bias=True)
#               (act): GELU(approximate='none')
#               (fc2): Linear(in_features=360, out_features=180, bias=True)
#               (drop): Dropout(p=0.0, inplace=False)
#             )
#           )
#           (3): SwinTransformerBlock(
#             dim=180, input_resolution=(48, 48), num_heads=6, window_size=8, shift_size=4, mlp_ratio=2
#             (norm1): LayerNorm((180,), eps=1e-05, elementwise_affine=True)
#             (attn): WindowAttention(
#               dim=180, window_size=(8, 8), num_heads=6
#               (qkv): Linear(in_features=180, out_features=540, bias=True)
#               (attn_drop): Dropout(p=0.0, inplace=False)
#               (proj): Linear(in_features=180, out_features=180, bias=True)
#               (proj_drop): Dropout(p=0.0, inplace=False)
#               (softmax): Softmax(dim=-1)
#             )
#             (drop_path): DropPath()
#             (norm2): LayerNorm((180,), eps=1e-05, elementwise_affine=True)
#             (mlp): Mlp(
#               (fc1): Linear(in_features=180, out_features=360, bias=True)
#               (act): GELU(approximate='none')
#               (fc2): Linear(in_features=360, out_features=180, bias=True)
#               (drop): Dropout(p=0.0, inplace=False)
#             )
#           )
#           (4): SwinTransformerBlock(
#             dim=180, input_resolution=(48, 48), num_heads=6, window_size=8, shift_size=0, mlp_ratio=2
#             (norm1): LayerNorm((180,), eps=1e-05, elementwise_affine=True)
#             (attn): WindowAttention(
#               dim=180, window_size=(8, 8), num_heads=6
#               (qkv): Linear(in_features=180, out_features=540, bias=True)
#               (attn_drop): Dropout(p=0.0, inplace=False)
#               (proj): Linear(in_features=180, out_features=180, bias=True)
#               (proj_drop): Dropout(p=0.0, inplace=False)
#               (softmax): Softmax(dim=-1)
#             )
#             (drop_path): DropPath()
#             (norm2): LayerNorm((180,), eps=1e-05, elementwise_affine=True)
#             (mlp): Mlp(
#               (fc1): Linear(in_features=180, out_features=360, bias=True)
#               (act): GELU(approximate='none')
#               (fc2): Linear(in_features=360, out_features=180, bias=True)
#               (drop): Dropout(p=0.0, inplace=False)
#             )
#           )
#           (5): SwinTransformerBlock(
#             dim=180, input_resolution=(48, 48), num_heads=6, window_size=8, shift_size=4, mlp_ratio=2
#             (norm1): LayerNorm((180,), eps=1e-05, elementwise_affine=True)
#             (attn): WindowAttention(
#               dim=180, window_size=(8, 8), num_heads=6
#               (qkv): Linear(in_features=180, out_features=540, bias=True)
#               (attn_drop): Dropout(p=0.0, inplace=False)
#               (proj): Linear(in_features=180, out_features=180, bias=True)
#               (proj_drop): Dropout(p=0.0, inplace=False)
#               (softmax): Softmax(dim=-1)
#             )
#             (drop_path): DropPath()
#             (norm2): LayerNorm((180,), eps=1e-05, elementwise_affine=True)
#             (mlp): Mlp(
#               (fc1): Linear(in_features=180, out_features=360, bias=True)
#               (act): GELU(approximate='none')
#               (fc2): Linear(in_features=360, out_features=180, bias=True)
#               (drop): Dropout(p=0.0, inplace=False)
#             )
#           )
#         )
#       )
#       (conv): Conv2d(180, 180, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (patch_embed): PatchEmbed()
#       (patch_unembed): PatchUnEmbed()
#     )
#   )
#   (norm): LayerNorm((180,), eps=1e-05, elementwise_affine=True)
#   (conv_after_body): Conv2d(180, 180, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (conv_before_upsample): Sequential(
#     (0): Conv2d(180, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): LeakyReLU(negative_slope=0.01, inplace=True)
#   )
#   (upsample): Upsample(
#     (0): Conv2d(64, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): PixelShuffle(upscale_factor=2)
#     (2): Conv2d(64, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (3): PixelShuffle(upscale_factor=2)
#   )
#   (conv_last): Conv2d(64, 3, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
# )
# 2026-07-09 17:48:49,277 INFO: Loading SwinIR model from /kaggle/working/BasicSR/experiments/finetune_SwinIR_SRx4_SEM/models/net_g_10000.pth, with param key: [params].
# 2026-07-09 17:48:49,387 INFO: Use Exponential Moving Average with decay: 0.999
# /usr/local/lib/python3.12/dist-packages/torch/utils/data/dataloader.py:432: UserWarning: This DataLoader will create 6 worker processes in total. Our suggested max number of worker in current system is 4, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   self.check_worker_number_rationality()
# 2026-07-09 17:48:49,946 INFO: Network [SwinIR] is created.
# 2026-07-09 17:48:50,200 INFO: Loading SwinIR model from /kaggle/working/BasicSR/experiments/finetune_SwinIR_SRx4_SEM/models/net_g_10000.pth, with param key: [params_ema].
# 2026-07-09 17:48:50,280 INFO: Loss [L1Loss] is created.
# 2026-07-09 17:48:50,283 INFO: Model [SwinIRModel] is created.
# 2026-07-09 17:48:50,291 INFO: Resuming training from epoch: 2, iter: 10000.
# /usr/local/lib/python3.12/dist-packages/torch/utils/data/dataloader.py:432: UserWarning: This DataLoader will create 6 worker processes in total. Our suggested max number of worker in current system is 4, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   self.check_worker_number_rationality()
# <frozen runpy>:128: RuntimeWarning: 'basicsr.train' found in sys.modules after import of package 'basicsr', but prior to execution of 'basicsr.train'; this may result in unpredictable behaviour
# <frozen runpy>:128: RuntimeWarning: 'basicsr.train' found in sys.modules after import of package 'basicsr', but prior to execution of 'basicsr.train'; this may result in unpredictable behaviour
# <frozen runpy>:128: RuntimeWarning: 'basicsr.train' found in sys.modules after import of package 'basicsr', but prior to execution of 'basicsr.train'; this may result in unpredictable behaviour
# <frozen runpy>:128: RuntimeWarning: 'basicsr.train' found in sys.modules after import of package 'basicsr', but prior to execution of 'basicsr.train'; this may result in unpredictable behaviour
# <frozen runpy>:128: RuntimeWarning: 'basicsr.train' found in sys.modules after import of package 'basicsr', but prior to execution of 'basicsr.train'; this may result in unpredictable behaviour
# <frozen runpy>:128: RuntimeWarning: 'basicsr.train' found in sys.modules after import of package 'basicsr', but prior to execution of 'basicsr.train'; this may result in unpredictable behaviour
# <frozen runpy>:128: RuntimeWarning: 'basicsr.train' found in sys.modules after import of package 'basicsr', but prior to execution of 'basicsr.train'; this may result in unpredictable behaviour
# <frozen runpy>:128: RuntimeWarning: 'basicsr.train' found in sys.modules after import of package 'basicsr', but prior to execution of 'basicsr.train'; this may result in unpredictable behaviour
# <frozen runpy>:128: RuntimeWarning: 'basicsr.train' found in sys.modules after import of package 'basicsr', but prior to execution of 'basicsr.train'; this may result in unpredictable behaviour
# <frozen runpy>:128: RuntimeWarning: 'basicsr.train' found in sys.modules after import of package 'basicsr', but prior to execution of 'basicsr.train'; this may result in unpredictable behaviour
# <frozen runpy>:128: RuntimeWarning: 'basicsr.train' found in sys.modules after import of package 'basicsr', but prior to execution of 'basicsr.train'; this may result in unpredictable behaviour
# <frozen runpy>:128: RuntimeWarning: 'basicsr.train' found in sys.modules after import of package 'basicsr', but prior to execution of 'basicsr.train'; this may result in unpredictable behaviour
# 2026-07-09 17:49:14,088 INFO: Start training from epoch: 2, iter: 10000
# <frozen runpy>:128: RuntimeWarning: 'basicsr.train' found in sys.modules after import of package 'basicsr', but prior to execution of 'basicsr.train'; this may result in unpredictable behaviour
# <frozen runpy>:128: RuntimeWarning: 'basicsr.train' found in sys.modules after import of package 'basicsr', but prior to execution of 'basicsr.train'; this may result in unpredictable behaviour
# <frozen runpy>:128: RuntimeWarning: 'basicsr.train' found in sys.modules after import of package 'basicsr', but prior to execution of 'basicsr.train'; this may result in unpredictable behaviour
# <frozen runpy>:128: RuntimeWarning: 'basicsr.train' found in sys.modules after import of package 'basicsr', but prior to execution of 'basicsr.train'; this may result in unpredictable behaviour
# <frozen runpy>:128: RuntimeWarning: 'basicsr.train' found in sys.modules after import of package 'basicsr', but prior to execution of 'basicsr.train'; this may result in unpredictable behaviour
# <frozen runpy>:128: RuntimeWarning: 'basicsr.train' found in sys.modules after import of package 'basicsr', but prior to execution of 'basicsr.train'; this may result in unpredictable behaviour
# <frozen runpy>:128: RuntimeWarning: 'basicsr.train' found in sys.modules after import of package 'basicsr', but prior to execution of 'basicsr.train'; this may result in unpredictable behaviour
# <frozen runpy>:128: RuntimeWarning: 'basicsr.train' found in sys.modules after import of package 'basicsr', but prior to execution of 'basicsr.train'; this may result in unpredictable behaviour
# <frozen runpy>:128: RuntimeWarning: 'basicsr.train' found in sys.modules after import of package 'basicsr', but prior to execution of 'basicsr.train'; this may result in unpredictable behaviour
# <frozen runpy>:128: RuntimeWarning: 'basicsr.train' found in sys.modules after import of package 'basicsr', but prior to execution of 'basicsr.train'; this may result in unpredictable behaviour
# <frozen runpy>:128: RuntimeWarning: 'basicsr.train' found in sys.modules after import of package 'basicsr', but prior to execution of 'basicsr.train'; this may result in unpredictable behaviour
# <frozen runpy>:128: RuntimeWarning: 'basicsr.train' found in sys.modules after import of package 'basicsr', but prior to execution of 'basicsr.train'; this may result in unpredictable behaviour
# 2026-07-09 17:51:22,006 INFO: [finet..][epoch:  2, iter:  10,100, lr:(1.000e-04,)] [eta: 7:09:19, time (data): 1.279 (0.299)] l_pix: 3.1597e-02
# 2026-07-09 17:53:00,443 INFO: [finet..][epoch:  2, iter:  10,200, lr:(1.000e-04,)] [eta: 5:53:38, time (data): 1.132 (0.151)] l_pix: 3.8512e-02
# 2026-07-09 17:54:38,137 INFO: [finet..][epoch:  2, iter:  10,300, lr:(1.000e-04,)] [eta: 5:26:26, time (data): 0.977 (0.003)] l_pix: 3.1628e-02
# 2026-07-09 17:56:15,572 INFO: [finet..][epoch:  2, iter:  10,400, lr:(1.000e-04,)] [eta: 5:11:49, time (data): 0.976 (0.003)] l_pix: 3.3543e-02
# 2026-07-09 17:57:52,674 INFO: [finet..][epoch:  2, iter:  10,500, lr:(1.000e-04,)] [eta: 5:02:12, time (data): 0.971 (0.003)] l_pix: 3.6890e-02
# 2026-07-09 17:59:29,652 INFO: [finet..][epoch:  2, iter:  10,600, lr:(1.000e-04,)] [eta: 4:55:11, time (data): 0.970 (0.003)] l_pix: 2.4216e-02
# 2026-07-09 18:01:06,751 INFO: [finet..][epoch:  2, iter:  10,700, lr:(1.000e-04,)] [eta: 4:49:46, time (data): 0.971 (0.003)] l_pix: 2.8266e-02
# 2026-07-09 18:02:43,875 INFO: [finet..][epoch:  2, iter:  10,800, lr:(1.000e-04,)] [eta: 4:45:18, time (data): 0.971 (0.003)] l_pix: 2.6555e-02
# 2026-07-09 18:04:21,023 INFO: [finet..][epoch:  2, iter:  10,900, lr:(1.000e-04,)] [eta: 4:41:28, time (data): 0.971 (0.003)] l_pix: 2.9590e-02
# 2026-07-09 18:05:58,230 INFO: [finet..][epoch:  2, iter:  11,000, lr:(1.000e-04,)] [eta: 4:38:06, time (data): 0.972 (0.003)] l_pix: 3.2641e-02
# 2026-07-09 18:07:35,352 INFO: [finet..][epoch:  2, iter:  11,100, lr:(1.000e-04,)] [eta: 4:35:01, time (data): 0.971 (0.003)] l_pix: 3.7757e-02
# 2026-07-09 18:09:12,466 INFO: [finet..][epoch:  2, iter:  11,200, lr:(1.000e-04,)] [eta: 4:32:11, time (data): 0.971 (0.003)] l_pix: 2.9470e-02
# <frozen runpy>:128: RuntimeWarning: 'basicsr.train' found in sys.modules after import of package 'basicsr', but prior to execution of 'basicsr.train'; this may result in unpredictable behaviour
# <frozen runpy>:128: RuntimeWarning: 'basicsr.train' found in sys.modules after import of package 'basicsr', but prior to execution of 'basicsr.train'; this may result in unpredictable behaviour
# <frozen runpy>:128: RuntimeWarning: 'basicsr.train' found in sys.modules after import of package 'basicsr', but prior to execution of 'basicsr.train'; this may result in unpredictable behaviour
# <frozen runpy>:128: RuntimeWarning: 'basicsr.train' found in sys.modules after import of package 'basicsr', but prior to execution of 'basicsr.train'; this may result in unpredictable behaviour
# <frozen runpy>:128: RuntimeWarning: 'basicsr.train' found in sys.modules after import of package 'basicsr', but prior to execution of 'basicsr.train'; this may result in unpredictable behaviour
# <frozen runpy>:128: RuntimeWarning: 'basicsr.train' found in sys.modules after import of package 'basicsr', but prior to execution of 'basicsr.train'; this may result in unpredictable behaviour
# <frozen runpy>:128: RuntimeWarning: 'basicsr.train' found in sys.modules after import of package 'basicsr', but prior to execution of 'basicsr.train'; this may result in unpredictable behaviour
# <frozen runpy>:128: RuntimeWarning: 'basicsr.train' found in sys.modules after import of package 'basicsr', but prior to execution of 'basicsr.train'; this may result in unpredictable behaviour
# <frozen runpy>:128: RuntimeWarning: 'basicsr.train' found in sys.modules after import of package 'basicsr', but prior to execution of 'basicsr.train'; this may result in unpredictable behaviour
# <frozen runpy>:128: RuntimeWarning: 'basicsr.train' found in sys.modules after import of package 'basicsr', but prior to execution of 'basicsr.train'; this may result in unpredictable behaviour
# <frozen runpy>:128: RuntimeWarning: 'basicsr.train' found in sys.modules after import of package 'basicsr', but prior to execution of 'basicsr.train'; this may result in unpredictable behaviour
# <frozen runpy>:128: RuntimeWarning: 'basicsr.train' found in sys.modules after import of package 'basicsr', but prior to execution of 'basicsr.train'; this may result in unpredictable behaviour
# 2026-07-09 18:11:18,332 INFO: [finet..][epoch:  3, iter:  11,300, lr:(1.000e-04,)] [eta: 4:35:25, time (data): 0.987 (0.003)] l_pix: 2.3955e-02
# 2026-07-09 18:12:56,121 INFO: [finet..][epoch:  3, iter:  11,400, lr:(1.000e-04,)] [eta: 4:32:36, time (data): 0.982 (0.003)] l_pix: 3.7992e-02
# 2026-07-09 18:14:32,785 INFO: [finet..][epoch:  3, iter:  11,500, lr:(1.000e-04,)] [eta: 4:29:44, time (data): 0.966 (0.003)] l_pix: 2.1505e-02
# 2026-07-09 18:16:09,637 INFO: [finet..][epoch:  3, iter:  11,600, lr:(1.000e-04,)] [eta: 4:27:03, time (data): 0.967 (0.003)] l_pix: 2.6695e-02
# 2026-07-09 18:17:46,284 INFO: [finet..][epoch:  3, iter:  11,700, lr:(1.000e-04,)] [eta: 4:24:28, time (data): 0.967 (0.003)] l_pix: 3.7059e-02
# 2026-07-09 18:19:22,568 INFO: [finet..][epoch:  3, iter:  11,800, lr:(1.000e-04,)] [eta: 4:21:57, time (data): 0.965 (0.003)] l_pix: 2.2405e-02
# 2026-07-09 18:20:59,615 INFO: [finet..][epoch:  3, iter:  11,900, lr:(1.000e-04,)] [eta: 4:19:37, time (data): 0.971 (0.003)] l_pix: 4.7458e-02
# 2026-07-09 18:22:37,106 INFO: [finet..][epoch:  3, iter:  12,000, lr:(1.000e-04,)] [eta: 4:17:25, time (data): 0.973 (0.003)] l_pix: 2.9519e-02
# 2026-07-09 18:24:13,835 INFO: [finet..][epoch:  3, iter:  12,100, lr:(1.000e-04,)] [eta: 4:15:11, time (data): 0.967 (0.003)] l_pix: 2.8403e-02
# 2026-07-09 18:25:51,181 INFO: [finet..][epoch:  3, iter:  12,200, lr:(1.000e-04,)] [eta: 4:13:04, time (data): 0.971 (0.003)] l_pix: 2.9313e-02
# 2026-07-09 18:27:29,312 INFO: [finet..][epoch:  3, iter:  12,300, lr:(1.000e-04,)] [eta: 4:11:06, time (data): 0.982 (0.003)] l_pix: 3.4775e-02
# 2026-07-09 18:29:06,992 INFO: [finet..][epoch:  3, iter:  12,400, lr:(1.000e-04,)] [eta: 4:09:06, time (data): 0.979 (0.003)] l_pix: 2.7869e-02
# <frozen runpy>:128: RuntimeWarning: 'basicsr.train' found in sys.modules after import of package 'basicsr', but prior to execution of 'basicsr.train'; this may result in unpredictable behaviour
# <frozen runpy>:128: RuntimeWarning: 'basicsr.train' found in sys.modules after import of package 'basicsr', but prior to execution of 'basicsr.train'; this may result in unpredictable behaviour
# <frozen runpy>:128: RuntimeWarning: 'basicsr.train' found in sys.modules after import of package 'basicsr', but prior to execution of 'basicsr.train'; this may result in unpredictable behaviour
# <frozen runpy>:128: RuntimeWarning: 'basicsr.train' found in sys.modules after import of package 'basicsr', but prior to execution of 'basicsr.train'; this may result in unpredictable behaviour
# <frozen runpy>:128: RuntimeWarning: 'basicsr.train' found in sys.modules after import of package 'basicsr', but prior to execution of 'basicsr.train'; this may result in unpredictable behaviour
# <frozen runpy>:128: RuntimeWarning: 'basicsr.train' found in sys.modules after import of package 'basicsr', but prior to execution of 'basicsr.train'; this may result in unpredictable behaviour
# <frozen runpy>:128: RuntimeWarning: 'basicsr.train' found in sys.modules after import of package 'basicsr', but prior to execution of 'basicsr.train'; this may result in unpredictable behaviour
# <frozen runpy>:128: RuntimeWarning: 'basicsr.train' found in sys.modules after import of package 'basicsr', but prior to execution of 'basicsr.train'; this may result in unpredictable behaviour
# <frozen runpy>:128: RuntimeWarning: 'basicsr.train' found in sys.modules after import of package 'basicsr', but prior to execution of 'basicsr.train'; this may result in unpredictable behaviour
# <frozen runpy>:128: RuntimeWarning: 'basicsr.train' found in sys.modules after import of package 'basicsr', but prior to execution of 'basicsr.train'; this may result in unpredictable behaviour
# <frozen runpy>:128: RuntimeWarning: 'basicsr.train' found in sys.modules after import of package 'basicsr', but prior to execution of 'basicsr.train'; this may result in unpredictable behaviour
# <frozen runpy>:128: RuntimeWarning: 'basicsr.train' found in sys.modules after import of package 'basicsr', but prior to execution of 'basicsr.train'; this may result in unpredictable behaviour
# 2026-07-09 18:31:12,267 INFO: [finet..][epoch:  4, iter:  12,500, lr:(1.000e-04,)] [eta: 4:09:50, time (data): 0.984 (0.003)] l_pix: 3.2518e-02
# 2026-07-09 18:32:50,851 INFO: [finet..][epoch:  4, iter:  12,600, lr:(1.000e-04,)] [eta: 4:07:51, time (data): 0.985 (0.003)] l_pix: 4.2514e-02
# 2026-07-09 18:34:29,145 INFO: [finet..][epoch:  4, iter:  12,700, lr:(1.000e-04,)] [eta: 4:05:52, time (data): 0.980 (0.003)] l_pix: 3.0555e-02
# 2026-07-09 18:36:06,803 INFO: [finet..][epoch:  4, iter:  12,800, lr:(1.000e-04,)] [eta: 4:03:52, time (data): 0.978 (0.003)] l_pix: 3.2271e-02
# 2026-07-09 18:37:44,575 INFO: [finet..][epoch:  4, iter:  12,900, lr:(1.000e-04,)] [eta: 4:01:53, time (data): 0.978 (0.003)] l_pix: 3.0708e-02
# 2026-07-09 18:39:22,738 INFO: [finet..][epoch:  4, iter:  13,000, lr:(1.000e-04,)] [eta: 3:59:58, time (data): 0.980 (0.003)] l_pix: 3.6142e-02
# 2026-07-09 18:41:00,751 INFO: [finet..][epoch:  4, iter:  13,100, lr:(1.000e-04,)] [eta: 3:58:03, time (data): 0.980 (0.003)] l_pix: 4.6083e-02
# 2026-07-09 18:42:38,456 INFO: [finet..][epoch:  4, iter:  13,200, lr:(1.000e-04,)] [eta: 3:56:08, time (data): 0.978 (0.003)] l_pix: 3.9713e-02
# 2026-07-09 18:44:16,539 INFO: [finet..][epoch:  4, iter:  13,300, lr:(1.000e-04,)] [eta: 3:54:15, time (data): 0.979 (0.003)] l_pix: 2.2256e-02
# 2026-07-09 18:45:54,158 INFO: [finet..][epoch:  4, iter:  13,400, lr:(1.000e-04,)] [eta: 3:52:22, time (data): 0.977 (0.003)] l_pix: 4.0789e-02
# 2026-07-09 18:47:31,906 INFO: [finet..][epoch:  4, iter:  13,500, lr:(1.000e-04,)] [eta: 3:50:29, time (data): 0.977 (0.003)] l_pix: 3.1769e-02
# 2026-07-09 18:49:09,977 INFO: [finet..][epoch:  4, iter:  13,600, lr:(1.000e-04,)] [eta: 3:48:39, time (data): 0.979 (0.003)] l_pix: 2.8308e-02
# <frozen runpy>:128: RuntimeWarning: 'basicsr.train' found in sys.modules after import of package 'basicsr', but prior to execution of 'basicsr.train'; this may result in unpredictable behaviour
# <frozen runpy>:128: RuntimeWarning: 'basicsr.train' found in sys.modules after import of package 'basicsr', but prior to execution of 'basicsr.train'; this may result in unpredictable behaviour
# <frozen runpy>:128: RuntimeWarning: 'basicsr.train' found in sys.modules after import of package 'basicsr', but prior to execution of 'basicsr.train'; this may result in unpredictable behaviour
# <frozen runpy>:128: RuntimeWarning: 'basicsr.train' found in sys.modules after import of package 'basicsr', but prior to execution of 'basicsr.train'; this may result in unpredictable behaviour
# <frozen runpy>:128: RuntimeWarning: 'basicsr.train' found in sys.modules after import of package 'basicsr', but prior to execution of 'basicsr.train'; this may result in unpredictable behaviour
# <frozen runpy>:128: RuntimeWarning: 'basicsr.train' found in sys.modules after import of package 'basicsr', but prior to execution of 'basicsr.train'; this may result in unpredictable behaviour
# <frozen runpy>:128: RuntimeWarning: 'basicsr.train' found in sys.modules after import of package 'basicsr', but prior to execution of 'basicsr.train'; this may result in unpredictable behaviour
# <frozen runpy>:128: RuntimeWarning: 'basicsr.train' found in sys.modules after import of package 'basicsr', but prior to execution of 'basicsr.train'; this may result in unpredictable behaviour
# <frozen runpy>:128: RuntimeWarning: 'basicsr.train' found in sys.modules after import of package 'basicsr', but prior to execution of 'basicsr.train'; this may result in unpredictable behaviour
# <frozen runpy>:128: RuntimeWarning: 'basicsr.train' found in sys.modules after import of package 'basicsr', but prior to execution of 'basicsr.train'; this may result in unpredictable behaviour
# <frozen runpy>:128: RuntimeWarning: 'basicsr.train' found in sys.modules after import of package 'basicsr', but prior to execution of 'basicsr.train'; this may result in unpredictable behaviour
# <frozen runpy>:128: RuntimeWarning: 'basicsr.train' found in sys.modules after import of package 'basicsr', but prior to execution of 'basicsr.train'; this may result in unpredictable behaviour
# 2026-07-09 18:51:16,429 INFO: [finet..][epoch:  5, iter:  13,700, lr:(1.000e-04,)] [eta: 3:48:34, time (data): 0.994 (0.003)] l_pix: 2.4600e-02
# 2026-07-09 18:52:54,119 INFO: [finet..][epoch:  5, iter:  13,800, lr:(1.000e-04,)] [eta: 3:46:40, time (data): 0.985 (0.003)] l_pix: 2.6112e-02
# 2026-07-09 18:54:31,859 INFO: [finet..][epoch:  5, iter:  13,900, lr:(1.000e-04,)] [eta: 3:44:47, time (data): 0.975 (0.003)] l_pix: 3.3339e-02
# 2026-07-09 18:56:09,944 INFO: [finet..][epoch:  5, iter:  14,000, lr:(1.000e-04,)] [eta: 3:42:56, time (data): 0.978 (0.003)] l_pix: 2.9820e-02
# 2026-07-09 18:57:47,468 INFO: [finet..][epoch:  5, iter:  14,100, lr:(1.000e-04,)] [eta: 3:41:04, time (data): 0.977 (0.003)] l_pix: 2.1365e-02
# 2026-07-09 18:59:25,454 INFO: [finet..][epoch:  5, iter:  14,200, lr:(1.000e-04,)] [eta: 3:39:15, time (data): 0.978 (0.003)] l_pix: 2.8076e-02
# 2026-07-09 19:01:03,922 INFO: [finet..][epoch:  5, iter:  14,300, lr:(1.000e-04,)] [eta: 3:37:27, time (data): 0.986 (0.003)] l_pix: 2.7931e-02
# 2026-07-09 19:02:42,097 INFO: [finet..][epoch:  5, iter:  14,400, lr:(1.000e-04,)] [eta: 3:35:38, time (data): 0.983 (0.003)] l_pix: 2.5962e-02
# 2026-07-09 19:04:20,016 INFO: [finet..][epoch:  5, iter:  14,500, lr:(1.000e-04,)] [eta: 3:33:50, time (data): 0.980 (0.003)] l_pix: 2.3176e-02
# 2026-07-09 19:05:58,354 INFO: [finet..][epoch:  5, iter:  14,600, lr:(1.000e-04,)] [eta: 3:32:03, time (data): 0.982 (0.003)] l_pix: 3.2462e-02
# 2026-07-09 19:07:36,686 INFO: [finet..][epoch:  5, iter:  14,700, lr:(1.000e-04,)] [eta: 3:30:16, time (data): 0.981 (0.003)] l_pix: 2.3174e-02
# 2026-07-09 19:09:14,601 INFO: [finet..][epoch:  5, iter:  14,800, lr:(1.000e-04,)] [eta: 3:28:29, time (data): 0.980 (0.003)] l_pix: 5.8318e-02
# <frozen runpy>:128: RuntimeWarning: 'basicsr.train' found in sys.modules after import of package 'basicsr', but prior to execution of 'basicsr.train'; this may result in unpredictable behaviour
# <frozen runpy>:128: RuntimeWarning: 'basicsr.train' found in sys.modules after import of package 'basicsr', but prior to execution of 'basicsr.train'; this may result in unpredictable behaviour
# <frozen runpy>:128: RuntimeWarning: 'basicsr.train' found in sys.modules after import of package 'basicsr', but prior to execution of 'basicsr.train'; this may result in unpredictable behaviour
# <frozen runpy>:128: RuntimeWarning: 'basicsr.train' found in sys.modules after import of package 'basicsr', but prior to execution of 'basicsr.train'; this may result in unpredictable behaviour
# <frozen runpy>:128: RuntimeWarning: 'basicsr.train' found in sys.modules after import of package 'basicsr', but prior to execution of 'basicsr.train'; this may result in unpredictable behaviour
# <frozen runpy>:128: RuntimeWarning: 'basicsr.train' found in sys.modules after import of package 'basicsr', but prior to execution of 'basicsr.train'; this may result in unpredictable behaviour
# <frozen runpy>:128: RuntimeWarning: 'basicsr.train' found in sys.modules after import of package 'basicsr', but prior to execution of 'basicsr.train'; this may result in unpredictable behaviour
# <frozen runpy>:128: RuntimeWarning: 'basicsr.train' found in sys.modules after import of package 'basicsr', but prior to execution of 'basicsr.train'; this may result in unpredictable behaviour
# <frozen runpy>:128: RuntimeWarning: 'basicsr.train' found in sys.modules after import of package 'basicsr', but prior to execution of 'basicsr.train'; this may result in unpredictable behaviour
# <frozen runpy>:128: RuntimeWarning: 'basicsr.train' found in sys.modules after import of package 'basicsr', but prior to execution of 'basicsr.train'; this may result in unpredictable behaviour
# <frozen runpy>:128: RuntimeWarning: 'basicsr.train' found in sys.modules after import of package 'basicsr', but prior to execution of 'basicsr.train'; this may result in unpredictable behaviour
# <frozen runpy>:128: RuntimeWarning: 'basicsr.train' found in sys.modules after import of package 'basicsr', but prior to execution of 'basicsr.train'; this may result in unpredictable behaviour
# 2026-07-09 19:11:20,287 INFO: [finet..][epoch:  6, iter:  14,900, lr:(1.000e-04,)] [eta: 3:27:52, time (data): 0.990 (0.003)] l_pix: 2.7397e-02
# 2026-07-09 19:12:57,145 INFO: [finet..][epoch:  6, iter:  15,000, lr:(1.000e-04,)] [eta: 3:26:01, time (data): 0.978 (0.003)] l_pix: 2.4973e-02
# 2026-07-09 19:12:57,146 INFO: Saving models and training states.
# 2026-07-09 19:14:35,150 INFO: [finet..][epoch:  6, iter:  15,100, lr:(1.000e-04,)] [eta: 3:24:13, time (data): 0.972 (0.003)] l_pix: 2.1952e-02
# 2026-07-09 19:16:12,669 INFO: [finet..][epoch:  6, iter:  15,200, lr:(1.000e-04,)] [eta: 3:22:24, time (data): 0.974 (0.003)] l_pix: 2.7419e-02
# 2026-07-09 19:17:50,038 INFO: [finet..][epoch:  6, iter:  15,300, lr:(1.000e-04,)] [eta: 3:20:36, time (data): 0.975 (0.003)] l_pix: 3.5025e-02
# 2026-07-09 19:19:27,368 INFO: [finet..][epoch:  6, iter:  15,400, lr:(1.000e-04,)] [eta: 3:18:48, time (data): 0.974 (0.003)] l_pix: 3.1472e-02
# 2026-07-09 19:21:05,004 INFO: [finet..][epoch:  6, iter:  15,500, lr:(1.000e-04,)] [eta: 3:17:01, time (data): 0.977 (0.003)] l_pix: 2.9891e-02
# 2026-07-09 19:22:42,476 INFO: [finet..][epoch:  6, iter:  15,600, lr:(1.000e-04,)] [eta: 3:15:13, time (data): 0.976 (0.003)] l_pix: 2.2534e-02
# 2026-07-09 19:24:20,027 INFO: [finet..][epoch:  6, iter:  15,700, lr:(1.000e-04,)] [eta: 3:13:27, time (data): 0.976 (0.003)] l_pix: 3.2660e-02
# 2026-07-09 19:25:57,870 INFO: [finet..][epoch:  6, iter:  15,800, lr:(1.000e-04,)] [eta: 3:11:41, time (data): 0.977 (0.003)] l_pix: 3.2632e-02
# 2026-07-09 19:27:35,596 INFO: [finet..][epoch:  6, iter:  15,900, lr:(1.000e-04,)] [eta: 3:09:55, time (data): 0.976 (0.003)] l_pix: 2.9801e-02
# 2026-07-09 19:29:14,077 INFO: [finet..][epoch:  6, iter:  16,000, lr:(1.000e-04,)] [eta: 3:08:11, time (data): 0.981 (0.003)] l_pix: 3.3139e-02
# <frozen runpy>:128: RuntimeWarning: 'basicsr.train' found in sys.modules after import of package 'basicsr', but prior to execution of 'basicsr.train'; this may result in unpredictable behaviour
# <frozen runpy>:128: RuntimeWarning: 'basicsr.train' found in sys.modules after import of package 'basicsr', but prior to execution of 'basicsr.train'; this may result in unpredictable behaviour
# <frozen runpy>:128: RuntimeWarning: 'basicsr.train' found in sys.modules after import of package 'basicsr', but prior to execution of 'basicsr.train'; this may result in unpredictable behaviour
# <frozen runpy>:128: RuntimeWarning: 'basicsr.train' found in sys.modules after import of package 'basicsr', but prior to execution of 'basicsr.train'; this may result in unpredictable behaviour
# <frozen runpy>:128: RuntimeWarning: 'basicsr.train' found in sys.modules after import of package 'basicsr', but prior to execution of 'basicsr.train'; this may result in unpredictable behaviour
# <frozen runpy>:128: RuntimeWarning: 'basicsr.train' found in sys.modules after import of package 'basicsr', but prior to execution of 'basicsr.train'; this may result in unpredictable behaviour
# <frozen runpy>:128: RuntimeWarning: 'basicsr.train' found in sys.modules after import of package 'basicsr', but prior to execution of 'basicsr.train'; this may result in unpredictable behaviour
# <frozen runpy>:128: RuntimeWarning: 'basicsr.train' found in sys.modules after import of package 'basicsr', but prior to execution of 'basicsr.train'; this may result in unpredictable behaviour
# <frozen runpy>:128: RuntimeWarning: 'basicsr.train' found in sys.modules after import of package 'basicsr', but prior to execution of 'basicsr.train'; this may result in unpredictable behaviour
# <frozen runpy>:128: RuntimeWarning: 'basicsr.train' found in sys.modules after import of package 'basicsr', but prior to execution of 'basicsr.train'; this may result in unpredictable behaviour
# <frozen runpy>:128: RuntimeWarning: 'basicsr.train' found in sys.modules after import of package 'basicsr', but prior to execution of 'basicsr.train'; this may result in unpredictable behaviour
# <frozen runpy>:128: RuntimeWarning: 'basicsr.train' found in sys.modules after import of package 'basicsr', but prior to execution of 'basicsr.train'; this may result in unpredictable behaviour
# 2026-07-09 19:31:20,778 INFO: [finet..][epoch:  7, iter:  16,100, lr:(1.000e-04,)] [eta: 3:07:19, time (data): 0.999 (0.003)] l_pix: 3.2493e-02
# 2026-07-09 19:32:58,697 INFO: [finet..][epoch:  7, iter:  16,200, lr:(1.000e-04,)] [eta: 3:05:33, time (data): 0.987 (0.003)] l_pix: 2.6784e-02
# ...
# <frozen runpy>:128: RuntimeWarning: 'basicsr.train' found in sys.modules after import of package 'basicsr', but prior to execution of 'basicsr.train'; this may result in unpredictable behaviour
# <frozen runpy>:128: RuntimeWarning: 'basicsr.train' found in sys.modules after import of package 'basicsr', but prior to execution of 'basicsr.train'; this may result in unpredictable behaviour
# <frozen runpy>:128: RuntimeWarning: 'basicsr.train' found in sys.modules after import of package 'basicsr', but prior to execution of 'basicsr.train'; this may result in unpredictable behaviour
# <frozen runpy>:128: RuntimeWarning: 'basicsr.train' found in sys.modules after import of package 'basicsr', but prior to execution of 'basicsr.train'; this may result in unpredictable behaviour
# <frozen runpy>:128: RuntimeWarning: 'basicsr.train' found in sys.modules after import of package 'basicsr', but prior to execution of 'basicsr.train'; this may result in unpredictable behaviour
# <frozen runpy>:128: RuntimeWarning: 'basicsr.train' found in sys.modules after import of package 'basicsr', but prior to execution of 'basicsr.train'; this may result in unpredictable behaviour
# <frozen runpy>:128: RuntimeWarning: 'basicsr.train' found in sys.modules after import of package 'basicsr', but prior to execution of 'basicsr.train'; this may result in unpredictable behaviour
# <frozen runpy>:128: RuntimeWarning: 'basicsr.train' found in sys.modules after import of package 'basicsr', but prior to execution of 'basicsr.train'; this may result in unpredictable behaviour
# <frozen runpy>:128: RuntimeWarning: 'basicsr.train' found in sys.modules after import of package 'basicsr', but prior to execution of 'basicsr.train'; this may result in unpredictable behaviour
# <frozen runpy>:128: RuntimeWarning: 'basicsr.train' found in sys.modules after import of package 'basicsr', but prior to execution of 'basicsr.train'; this may result in unpredictable behaviour
# <frozen runpy>:128: RuntimeWarning: 'basicsr.train' found in sys.modules after import of package 'basicsr', but prior to execution of 'basicsr.train'; this may result in unpredictable behaviour
# <frozen runpy>:128: RuntimeWarning: 'basicsr.train' found in sys.modules after import of package 'basicsr', but prior to execution of 'basicsr.train'; this may result in unpredictable behaviour
# <frozen runpy>:128: RuntimeWarning: 'basicsr.train' found in sys.modules after import of package 'basicsr', but prior to execution of 'basicsr.train'; this may result in unpredictable behaviour
# <frozen runpy>:128: RuntimeWarning: 'basicsr.train' found in sys.modules after import of package 'basicsr', but prior to execution of 'basicsr.train'; this may result in unpredictable behaviour
# <frozen runpy>:128: RuntimeWarning: 'basicsr.train' found in sys.modules after import of package 'basicsr', but prior to execution of 'basicsr.train'; this may result in unpredictable behaviour
# <frozen runpy>:128: RuntimeWarning: 'basicsr.train' found in sys.modules after import of package 'basicsr', but prior to execution of 'basicsr.train'; this may result in unpredictable behaviour
# <frozen runpy>:128: RuntimeWarning: 'basicsr.train' found in sys.modules after import of package 'basicsr', but prior to execution of 'basicsr.train'; this may result in unpredictable behaviour
# <frozen runpy>:128: RuntimeWarning: 'basicsr.train' found in sys.modules after import of package 'basicsr', but prior to execution of 'basicsr.train'; this may result in unpredictable behaviour
# <frozen runpy>:128: RuntimeWarning: 'basicsr.train' found in sys.modules after import of package 'basicsr', but prior to execution of 'basicsr.train'; this may result in unpredictable behaviour
# <frozen runpy>:128: RuntimeWarning: 'basicsr.train' found in sys.modules after import of package 'basicsr', but prior to execution of 'basicsr.train'; this may result in unpredictable behaviour
# <frozen runpy>:128: RuntimeWarning: 'basicsr.train' found in sys.modules after import of package 'basicsr', but prior to execution of 'basicsr.train'; this may result in unpredictable behaviour
# <frozen runpy>:128: RuntimeWarning: 'basicsr.train' found in sys.modules after import of package 'basicsr', but prior to execution of 'basicsr.train'; this may result in unpredictable behaviour
# <frozen runpy>:128: RuntimeWarning: 'basicsr.train' found in sys.modules after import of package 'basicsr', but prior to execution of 'basicsr.train'; this may result in unpredictable behaviour
# <frozen runpy>:128: RuntimeWarning: 'basicsr.train' found in sys.modules after import of package 'basicsr', but prior to execution of 'basicsr.train'; this may result in unpredictable behaviour
# <frozen runpy>:128: RuntimeWarning: 'basicsr.train' found in sys.modules after import of package 'basicsr', but prior to execution of 'basicsr.train'; this may result in unpredictable behaviour
# <frozen runpy>:128: RuntimeWarning: 'basicsr.train' found in sys.modules after import of package 'basicsr', but prior to execution of 'basicsr.train'; this may result in unpredictable behaviour
# <frozen runpy>:128: RuntimeWarning: 'basicsr.train' found in sys.modules after import of package 'basicsr', but prior to execution of 'basicsr.train'; this may result in unpredictable behaviour
# <frozen runpy>:128: RuntimeWarning: 'basicsr.train' found in sys.modules after import of package 'basicsr', but prior to execution of 'basicsr.train'; this may result in unpredictable behaviour
# <frozen runpy>:128: RuntimeWarning: 'basicsr.train' found in sys.modules after import of package 'basicsr', but prior to execution of 'basicsr.train'; this may result in unpredictable behaviour
# <frozen runpy>:128: RuntimeWarning: 'basicsr.train' found in sys.modules after import of package 'basicsr', but prior to execution of 'basicsr.train'; this may result in unpredictable behaviour
# <frozen runpy>:128: RuntimeWarning: 'basicsr.train' found in sys.modules after import of package 'basicsr', but prior to execution of 'basicsr.train'; this may result in unpredictable behaviour
# <frozen runpy>:128: RuntimeWarning: 'basicsr.train' found in sys.modules after import of package 'basicsr', but prior to execution of 'basicsr.train'; this may result in unpredictable behaviour
# <frozen runpy>:128: RuntimeWarning: 'basicsr.train' found in sys.modules after import of package 'basicsr', but prior to execution of 'basicsr.train'; this may result in unpredictable behaviour
# <frozen runpy>:128: RuntimeWarning: 'basicsr.train' found in sys.modules after import of package 'basicsr', but prior to execution of 'basicsr.train'; this may result in unpredictable behaviour
# <frozen runpy>:128: RuntimeWarning: 'basicsr.train' found in sys.modules after import of package 'basicsr', but prior to execution of 'basicsr.train'; this may result in unpredictable behaviour
# <frozen runpy>:128: RuntimeWarning: 'basicsr.train' found in sys.modules after import of package 'basicsr', but prior to execution of 'basicsr.train'; this may result in unpredictable behaviour
# <frozen runpy>:128: RuntimeWarning: 'basicsr.train' found in sys.modules after import of package 'basicsr', but prior to execution of 'basicsr.train'; this may result in unpredictable behaviour
# <frozen runpy>:128: RuntimeWarning: 'basicsr.train' found in sys.modules after import of package 'basicsr', but prior to execution of 'basicsr.train'; this may result in unpredictable behaviour
# <frozen runpy>:128: RuntimeWarning: 'basicsr.train' found in sys.modules after import of package 'basicsr', but prior to execution of 'basicsr.train'; this may result in unpredictable behaviour
# <frozen runpy>:128: RuntimeWarning: 'basicsr.train' found in sys.modules after import of package 'basicsr', but prior to execution of 'basicsr.train'; this may result in unpredictable behaviour
# <frozen runpy>:128: RuntimeWarning: 'basicsr.train' found in sys.modules after import of package 'basicsr', but prior to execution of 'basicsr.train'; this may result in unpredictable behaviour
# <frozen runpy>:128: RuntimeWarning: 'basicsr.train' found in sys.modules after import of package 'basicsr', but prior to execution of 'basicsr.train'; this may result in unpredictable behaviour
# <frozen runpy>:128: RuntimeWarning: 'basicsr.train' found in sys.modules after import of package 'basicsr', but prior to execution of 'basicsr.train'; this may result in unpredictable behaviour
# <frozen runpy>:128: RuntimeWarning: 'basicsr.train' found in sys.modules after import of package 'basicsr', but prior to execution of 'basicsr.train'; this may result in unpredictable behaviour
# <frozen runpy>:128: RuntimeWarning: 'basicsr.train' found in sys.modules after import of package 'basicsr', but prior to execution of 'basicsr.train'; this may result in unpredictable behaviour
# <frozen runpy>:128: RuntimeWarning: 'basicsr.train' found in sys.modules after import of package 'basicsr', but prior to execution of 'basicsr.train'; this may result in unpredictable behaviour
# <frozen runpy>:128: RuntimeWarning: 'basicsr.train' found in sys.modules after import of package 'basicsr', but prior to execution of 'basicsr.train'; this may result in unpredictable behaviour
# <frozen runpy>:128: RuntimeWarning: 'basicsr.train' found in sys.modules after import of package 'basicsr', but prior to execution of 'basicsr.train'; this may result in unpredictable behaviour
# <frozen runpy>:128: RuntimeWarning: 'basicsr.train' found in sys.modules after import of package 'basicsr', but prior to execution of 'basicsr.train'; this may result in unpredictable behaviour
# <frozen runpy>:128: RuntimeWarning: 'basicsr.train' found in sys.modules after import of package 'basicsr', but prior to execution of 'basicsr.train'; this may result in unpredictable behaviour
# <frozen runpy>:128: RuntimeWarning: 'basicsr.train' found in sys.modules after import of package 'basicsr', but prior to execution of 'basicsr.train'; this may result in unpredictable behaviour
# <frozen runpy>:128: RuntimeWarning: 'basicsr.train' found in sys.modules after import of package 'basicsr', but prior to execution of 'basicsr.train'; this may result in unpredictable behaviour
# <frozen runpy>:128: RuntimeWarning: 'basicsr.train' found in sys.modules after import of package 'basicsr', but prior to execution of 'basicsr.train'; this may result in unpredictable behaviour
# <frozen runpy>:128: RuntimeWarning: 'basicsr.train' found in sys.modules after import of package 'basicsr', but prior to execution of 'basicsr.train'; this may result in unpredictable behaviour
# <frozen runpy>:128: RuntimeWarning: 'basicsr.train' found in sys.modules after import of package 'basicsr', but prior to execution of 'basicsr.train'; this may result in unpredictable behaviour
# <frozen runpy>:128: RuntimeWarning: 'basicsr.train' found in sys.modules after import of package 'basicsr', but prior to execution of 'basicsr.train'; this may result in unpredictable behaviour
# <frozen runpy>:128: RuntimeWarning: 'basicsr.train' found in sys.modules after import of package 'basicsr', but prior to execution of 'basicsr.train'; this may result in unpredictable behaviour
# <frozen runpy>:128: RuntimeWarning: 'basicsr.train' found in sys.modules after import of package 'basicsr', but prior to execution of 'basicsr.train'; this may result in unpredictable behaviour
# <frozen runpy>:128: RuntimeWarning: 'basicsr.train' found in sys.modules after import of package 'basicsr', but prior to execution of 'basicsr.train'; this may result in unpredictable behaviour
# <frozen runpy>:128: RuntimeWarning: 'basicsr.train' found in sys.modules after import of package 'basicsr', but prior to execution of 'basicsr.train'; this may result in unpredictable behaviour
# <frozen runpy>:128: RuntimeWarning: 'basicsr.train' found in sys.modules after import of package 'basicsr', but prior to execution of 'basicsr.train'; this may result in unpredictable behaviour
# <frozen runpy>:128: RuntimeWarning: 'basicsr.train' found in sys.modules after import of package 'basicsr', but prior to execution of 'basicsr.train'; this may result in unpredictable behaviour
# <frozen runpy>:128: RuntimeWarning: 'basicsr.train' found in sys.modules after import of package 'basicsr', but prior to execution of 'basicsr.train'; this may result in unpredictable behaviour
# <frozen runpy>:128: RuntimeWarning: 'basicsr.train' found in sys.modules after import of package 'basicsr', but prior to execution of 'basicsr.train'; this may result in unpredictable behaviour
# <frozen runpy>:128: RuntimeWarning: 'basicsr.train' found in sys.modules after import of package 'basicsr', but prior to execution of 'basicsr.train'; this may result in unpredictable behaviour
# <frozen runpy>:128: RuntimeWarning: 'basicsr.train' found in sys.modules after import of package 'basicsr', but prior to execution of 'basicsr.train'; this may result in unpredictable behaviour
# <frozen runpy>:128: RuntimeWarning: 'basicsr.train' found in sys.modules after import of package 'basicsr', but prior to execution of 'basicsr.train'; this may result in unpredictable behaviour
# <frozen runpy>:128: RuntimeWarning: 'basicsr.train' found in sys.modules after import of package 'basicsr', but prior to execution of 'basicsr.train'; this may result in unpredictable behaviour
# <frozen runpy>:128: RuntimeWarning: 'basicsr.train' found in sys.modules after import of package 'basicsr', but prior to execution of 'basicsr.train'; this may result in unpredictable behaviour
# <frozen runpy>:128: RuntimeWarning: 'basicsr.train' found in sys.modules after import of package 'basicsr', but prior to execution of 'basicsr.train'; this may result in unpredictable behaviour
# <frozen runpy>:128: RuntimeWarning: 'basicsr.train' found in sys.modules after import of package 'basicsr', but prior to execution of 'basicsr.train'; this may result in unpredictable behaviour
# <frozen runpy>:128: RuntimeWarning: 'basicsr.train' found in sys.modules after import of package 'basicsr', but prior to execution of 'basicsr.train'; this may result in unpredictable behaviour
# <frozen runpy>:128: RuntimeWarning: 'basicsr.train' found in sys.modules after import of package 'basicsr', but prior to execution of 'basicsr.train'; this may result in unpredictable behaviour
# <frozen runpy>:128: RuntimeWarning: 'basicsr.train' found in sys.modules after import of package 'basicsr', but prior to execution of 'basicsr.train'; this may result in unpredictable behaviour
# <frozen runpy>:128: RuntimeWarning: 'basicsr.train' found in sys.modules after import of package 'basicsr', but prior to execution of 'basicsr.train'; this may result in unpredictable behaviour
# <frozen runpy>:128: RuntimeWarning: 'basicsr.train' found in sys.modules after import of package 'basicsr', but prior to execution of 'basicsr.train'; this may result in unpredictable behaviour
# <frozen runpy>:128: RuntimeWarning: 'basicsr.train' found in sys.modules after import of package 'basicsr', but prior to execution of 'basicsr.train'; this may result in unpredictable behaviour
# <frozen runpy>:128: RuntimeWarning: 'basicsr.train' found in sys.modules after import of package 'basicsr', but prior to execution of 'basicsr.train'; this may result in unpredictable behaviour
# <frozen runpy>:128: RuntimeWarning: 'basicsr.train' found in sys.modules after import of package 'basicsr', but prior to execution of 'basicsr.train'; this may result in unpredictable behaviour
# <frozen runpy>:128: RuntimeWarning: 'basicsr.train' found in sys.modules after import of package 'basicsr', but prior to execution of 'basicsr.train'; this may result in unpredictable behaviour
# 2026-07-09 22:40:12,680 INFO: End of training. Time consumed: 4:50:58
# 2026-07-09 22:40:12,680 INFO: Save the latest model.
# [rank0]:[W709 22:40:17.112617298 ProcessGroupNCCL.cpp:1553] Warning: WARNING: destroy_process_group() was not called before program exit, which can leak resources. For more info, please see https://pytorch.org/docs/stable/distributed.html#shutdown (function operator())

# %% [markdown]
# ## 3. 结果分析

# %%
# 提取所有验证结果
logs = sorted([f for f in os.listdir(exp_dir) if f.endswith('.log')])
if logs:
    latest_log = os.path.join(exp_dir, logs[-1])
    with open(latest_log, 'r') as f:
        content = f.read()
    
    # 提取验证 PSNR
    import re
    val_matches = re.findall(r'psnr:\s+([\d.]+)\s+Best:\s+([\d.]+)\s+@\s+(\d+)', content)
    
    if val_matches:
        print('验证结果:')
        print(f'{"Iter":<10} {"PSNR":<10} {"Best PSNR":<12}')
        print('-' * 35)
        best_psnr = 0
        for psnr_val, best_val, iter_val in val_matches:
            marker = ' ←' if float(psnr_val) == float(best_val) else ''
            print(f'{iter_val:<10} {psnr_val:<10} {best_val:<12}{marker}')
    
    # 最后几行
    lines = content.strip().split('\n')
    print(f'\n日志最后 5 行:')
    for line in lines[-5:]:
        print(line)
else:
    print('未找到日志')
# Out:
# 日志最后 5 行:
# 2026-07-09 22:32:57,991 INFO: [finet..][epoch: 16, iter:  27,000, lr:(1.000e-04,)] [eta: 0:04:09, time (data): 0.967 (0.003)] l_pix: 3.4285e-02
# 2026-07-09 22:34:35,428 INFO: [finet..][epoch: 16, iter:  27,100, lr:(1.000e-04,)] [eta: 0:02:29, time (data): 0.968 (0.003)] l_pix: 2.4234e-02
# 2026-07-09 22:36:13,005 INFO: [finet..][epoch: 16, iter:  27,200, lr:(1.000e-04,)] [eta: 0:00:49, time (data): 0.975 (0.003)] l_pix: 4.0987e-02
# 2026-07-09 22:40:12,680 INFO: End of training. Time consumed: 4:50:58
# 2026-07-09 22:40:12,680 INFO: Save the latest model.

# %% [markdown]
# ## 4. 保存结果到 output
#
# 训练完成后，output 目录中的文件会被保存为 Kaggle Dataset，可以下载。

# %%
# /kaggle/working 整个目录在 Save and Run All 后会自动保存为 output
# 不需要手动复制，直接查看训练产物即可

print('训练产物位置:')
print(f'  模型权重: {models_dir}')
print(f'  训练状态: {states_dir}')

# 列出模型文件
print(f'\n模型文件:')
for f in sorted(os.listdir(models_dir)):
    size = os.path.getsize(os.path.join(models_dir, f)) / 1e6
    print(f'  {f} ({size:.1f}MB)')

# 列出训练状态文件
print(f'\n训练状态:')
for f in sorted(os.listdir(states_dir)):
    size = os.path.getsize(os.path.join(states_dir, f)) / 1e6
    print(f'  {f} ({size:.1f}MB)')

# 列出日志
print(f'\n日志文件:')
for f in sorted(os.listdir(exp_dir)):
    if f.endswith('.log'):
        size = os.path.getsize(os.path.join(exp_dir, f)) / 1e6
        print(f'  {f} ({size:.1f}MB)')
# Out:
# 训练产物位置:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_23/1346007131.py in <cell line: 0>()
#       3
#       4 print('训练产物位置:')
# ----> 5 print(f'  模型权重: {models_dir}')
#       6 print(f'  训练状态: {states_dir}')
#       7
#
# NameError: name 'models_dir' is not defined

# %%
# Kaggle Save and Run All 会自动保存 /kaggle/working 下所有内容
# 右侧面板 → Data → 下载即可

working_size = sum(
    os.path.getsize(os.path.join(r, f))
    for r, _, files in os.walk('/kaggle/working')
    for f in files
)
print(f'working 目录总大小: {working_size/1e9:.2f} GB')
print(f'训练完成！Save and Run All 后，右侧面板 → Data → 下载。')
